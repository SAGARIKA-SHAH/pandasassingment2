# %% [markdown]
# <a href="https://colab.research.google.com/github/SAGARIKA-SHAH/pandasassingment2/blob/main/Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
df1=pd.read_csv("https://raw.githubusercontent.com/SAGARIKA-SHAH/excelsheet1/main/college_1.csv?token=GHSAT0AAAAAABYL22L6MWH5LMMFPVVL53BKYYUGS4A")
df1
df2=pd.read_csv("https://raw.githubusercontent.com/SAGARIKA-SHAH/excelsheet1/main/college_2.csv?token=GHSAT0AAAAAABYL22L6VJAJHLR5YHXFHB3IYYUGSLA")
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df3=pd.concat([df1, df2], ignore_index=True)

df3.to_csv("College.csv")
college=pd.read_csv("College.csv")
college
# Out:
#      Unnamed: 0           Name  python  mysql  Previous Geekions  \
# 0             0      A.Dharani    82.0   20.0              24500
# 1             1    V.JEEVITHA     82.0   20.0              21740
# 2             2    HEMAVATHI.R   100.0  100.0              19680
# 3             3    Mugunthan S   100.0   47.0              10610
# 4             4    Sathammai.S   100.0    8.0               8980
# ..          ...            ...     ...    ...                ...
# 114         114  praveen raj j    24.0    0.0               2380
# 115         115     AMARNATH D    -1.0   12.0               1890
# 116         116           bala    32.0    0.0               1720
# 117         117           XY Z    -1.0   -1.0                  0
# 118         118      Hariharan    -1.0   -1.0                  0
#
#      CodeKata Score                                 Department  Rising  \
# 0             24500           Computer Science and Engineering       0
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
#1
unsatisfactory = df3[df3['CodeKata Score'] < 7000].head()
unsatisfactory.to_csv('unsatisfactory.csv',index=True)
pd.read_csv("unsatisfactory.csv")
# Out:
#    Unnamed: 0             Name  python  mysql  Previous Geekions  \
# 0           8       J.SUGANTHI    27.0  50.00               5860
# 1           9     thamizhpaana    29.0   0.00               5500
# 2          10  Iyappan Samiraj    50.0  24.00               5400
# 3          11     Ponniyamma.R   100.0  11.25               5380
# 4          12        SABAPATHI   100.0   0.00               5280
#
#    CodeKata Score                                 Department  Rising  \
# 0            5860  Electronics and Communication Engineering       0
# 1            5500           Computer Science and Engineering       0
# 2            5400  Electronics and Communication Engineering       0
# 3            5380           Computer Science and Engineering       0
# 4            5280           Computer Science and Engineering       0
#
#    python_en  computational_thinking
# 0        NaN                     NaN
# 1        NaN                     NaN
# 2        NaN                     NaN
# ...

# %%
#2
exceeded_expectations=df3[df3['CodeKata Score'] > 15000].head(5)
exceeded_expectations.to_csv('exceeded_expectations.csv',index=True)
pd.read_csv("exceeded_expectations.csv")
# Out:
#    Unnamed: 0           Name  python  mysql  Previous Geekions  \
# 0           0      A.Dharani    82.0   20.0              24500
# 1           1    V.JEEVITHA     82.0   20.0              21740
# 2           2    HEMAVATHI.R   100.0  100.0              19680
# 3          84  ASHOK KUMAR K   100.0   31.0              19400
#
#    CodeKata Score                              Department  Rising  python_en  \
# 0           24500        Computer Science and Engineering       0        NaN
# 1           21740        Computer Science and Engineering       0        NaN
# 2           19680        Computer Science and Engineering       0        NaN
# 3           19400  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     9.0

# %%
#3
needs_improvement=df3[(df3['CodeKata Score'] > 7000) & (df3["CodeKata Score"] <10000)].head(5)
needs_improvement.to_csv('needs_improvement.csv',index=True)
pd.read_csv("needs_improvement.csv")
# Out:
#    Unnamed: 0                  Name  python  mysql  Previous Geekions  \
# 0           4           Sathammai.S   100.0    8.0               8980
# 1           5          NIVEESHWAR S   100.0    0.0               8200
# 2           6         KALAIARASAN K    85.0   47.0               7750
# 3           7  MOHAMED ZUBAIR AHMED    82.0    4.0               7020
# 4          88             VIINU V P    -1.0   24.0               9150
#
#    CodeKata Score                                 Department  Rising  \
# 0            8980           Computer Science and Engineering       0
# 1            8200           Computer Science and Engineering       0
# 2            7880  Electronics and Communication Engineering     130
# 3            7020           Computer Science and Engineering       0
# 4            9150     Electronics and Electrical Engineering       0
#
#    python_en  computational_thinking
# 0        NaN                     NaN
# 1        NaN                     NaN
# ...

# %%
#4
reached_expectations=df3[(df3['CodeKata Score'] > 10000) & (df3["CodeKata Score"] <15000)].head(5)
reached_expectations.to_csv('reached_expectations.csv',index=True)
pd.read_csv("reached_expectations.csv")
# Out:
#    Unnamed: 0               Name  python  mysql  Previous Geekions  \
# 0           3        Mugunthan S   100.0   47.0              10610
# 1          85            Chandru     0.0    0.0              14150
# 2          86  Ganesh Ramkumar R    -1.0   24.0               8790
# 3          87    Bodipudi Harini    -1.0   35.0              10040
#
#    CodeKata Score                                 Department  Rising  \
# 0           10610           Computer Science and Engineering       0
# 1           14490           Computer Science and Engineering     340
# 2           10790           Computer Science and Engineering    2000
# 3           10040  Electronics and Communication Engineering       0
#
#    python_en  computational_thinking
# 0        NaN                     NaN
# 1       20.0                     0.0
# 2       55.0                     6.0
# 3        0.0                    -1.0

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
college["CodeKata Score"].mean()

college["Previous Geekions"].mean()
# Out:
# 3842.3529411764707

# %% [markdown]
# ###### No of students participated

# %%
len(df3)
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
college["python"].mean()
# Out:
# 54.35294117647059

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
Topper=df3.nlargest(n=3, columns=['CodeKata Score'])
Topper
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
topper=df3.nlargest(n=3, columns=['Previous Geekions'])
topper
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
import matplotlib.pyplot as plt

colors = ['pink', 'orange', 'yellow']

college.groupby(['Department']).mean().plot(kind='pie', y='CodeKata Score',title='Department wise performance',colors=colors,autopct='%1.0f%%')

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
cse=df3[df3["Department"]=='Computer Science and Engineering']
ece=df3[df3["Department"]=='Electronics and Communication Engineering']
eee=df3[df3["Department"]=='Electronics and Electrical Engineering']

csescore=cse[['Name','CodeKata Score']]
ecescore=ece[['Name','CodeKata Score']]
eeescore=eee[['Name','CodeKata Score']]

# %%
cstop=csescore.nlargest(n=5,columns=['CodeKata Score'])
cstop.plot(kind='bar',title="cse toppers", color="pink", xlabel='ranking', ylabel='score',)
ecetop=ecescore.nlargest(n=5,columns=['CodeKata Score'])
ecetop.plot(kind='bar',title="ece toppers", color="orange", xlabel='ranking', ylabel='score')
eetop=eeescore.nlargest(n=5,columns=['CodeKata Score'])
eetop.plot(kind='bar',title="eee toppers", color="yellow", xlabel='ranking', ylabel='score')

# %%
cse_x=cstop['Name'].tolist()
cse_y=cstop['CodeKata Score'].tolist()
ece_x=cstop['Name'].tolist()
ece_y=cstop['CodeKata Score'].tolist()
eee_x=cstop['Name'].tolist()
eee_y=cstop['CodeKata Score'].tolist()
plt.bar(cse_x,cse_y,color="pink",width = 0.5)
plt.xticks(rotation=90)
plt.xlabel("Names of toppers")
plt.ylabel("codekata scores")
plt.show()
plt.bar(ece_x,ece_y,color="orange",width = 0.5)
plt.xticks(rotation=90)
plt.xlabel("Names of toppers")
plt.ylabel("codekata scores")
plt.show()
plt.bar(eee_x,eee_y,color="yellow",width =0.5)
plt.xticks(rotation=90)
plt.xlabel("Names of toppers")
plt.ylabel("codekata scores")
plt.show()
